# %%
import ast
import re

curr_top = ""

with open("topics") as file:
    for line in file:
        if line[0].isalpha():
            curr_top = line
        elif line == "\n" or line == "":
            continue
        else:
            modified_line = re.sub(r"^(100|[1-9][0-9]?)\.\s", "", line)
            k = ast.literal_eval(modified_line)
            act_tup = (curr_top.strip(), k)
            # Make any changes you want here, or alternatively pull the modified_line to a broader scope if you want to work with it outside the with and for loop
            print(act_tup)
# Out:
# ('Fruits', ('Apples are more versatile than oranges', 'Oranges are more versatile than apples'))
# ('Fruits', ('Bananas are better for smoothies than strawberries', 'Strawberries are better for smoothies than bananas'))
# ('Fruits', ('Grapes are tastier than cherries', 'Cherries are tastier than grapes'))
# ('Fruits', ('Mangoes are the best tropical fruit', 'Pineapples are the best tropical fruit'))
# ('Fruits', ('Watermelon is the ultimate summer fruit', 'Peaches are the ultimate summer fruit'))
# ('Fruits', ('Raspberries are more delicious than blueberries', 'Blueberries are more delicious than raspberries'))
# ('Fruits', ('Pomegranates are better for health than kiwis', 'Kiwis are better for health than pomegranates'))
# ('Fruits', ('Coconuts have more uses than avocados', 'Avocados have more uses than coconuts'))
# ('Fruits', ('Lemons are better than limes', 'Limes are better than lemons'))
# ('Fruits', ('Cherries are better eaten fresh than in pies', 'Cherries are better in pies than eaten fresh'))
# ('Fruits', ('Grapefruits are tastier than oranges', 'Oranges are tastier than grapefruits'))
# ('Fruits', ('Figs are a more interesting fruit than dates', 'Dates are a more interesting fruit than figs'))
# ('Fruits', ('Blackberries are better than raspberries', 'Raspberries are better than blackberries'))
# ('Fruits', ('Dried fruits are healthier than fresh fruits', 'Fresh fruits are healthier than dried fruits'))
# ('Fruits', ('Bananas are better for energy before a workout than apples', 'Apples are better for energy before a workout than bananas'))
# ('Fruits', ('Peaches are sweeter than nectarines', 'Nectarines are sweeter than peaches'))
# ('Fruits', ('Tangerines are easier to peel than oranges', 'Oranges are easier to peel than tangerines'))
# ('Fruits', ('Pineapple belongs on pizza', 'Pineapple does not belong on pizza'))
# ('Fruits', ('Apples are more nutritious than bananas', 'Bananas are more nutritious than apples'))
# ('Fruits', ('Juicing fruits is better than eating them whole', 'Eating fruits whole is better than juicing them'))
# ('Fruits', ('Oranges are more refreshing than apples', 'Apples are more refreshing than oranges'))
# ('Fruits', ('Ripe bananas have a better flavor than ripe mangoes', 'Ripe mangoes have a better flavor than ripe bananas'))
# ('Fruits', ('Fruit salad is better with melons than without', 'Fruit salad is better without melons'))
# ('Fruits', ('Strawberries are the best berry', 'Blueberries are the best berry'))
# ('Fruits', ('Lychee is the best exotic fruit', 'Dragon fruit is the best exotic fruit'))
# ('Fruits', ('Citrus fruits are essential for winter health', 'Berries are essential for winter health'))
# ('Fruits', ('Carambola (star fruit) is more visually appealing than pomelo', 'Pomelo is more visually appealing than carambola'))
# ('Fruits', ('Frozen fruit is better for smoothies than fresh fruit', 'Fresh fruit is better for smoothies than frozen fruit'))
# ('Fruits', ('Cranberries are better than blueberries', 'Blueberries are better than cranberries'))
# ('Fruits', ('Papaya is the best fruit for digestion', 'Pineapple is the best fruit for digestion'))
# ('Fruits', ('Plums are tastier than apricots', 'Apricots are tastier than plums'))
# ('Fruits', ('Ripe figs are the best dessert fruit', 'Ripe peaches are the best dessert fruit'))
# ('Fruits', ('Pumpkin is a fruit', 'Pumpkin is not a fruit'))
# ('Fruits', ('Mango juice is better than apple juice', 'Apple juice is better than mango juice'))
# ('Fruits', ('Banana bread is a great way to use ripe bananas', 'Banana bread is overrated'))
# ('Fruits', ('Kiwi is more exotic than dragon fruit', 'Dragon fruit is more exotic than kiwi'))
# ('Fruits', ('Peaches are better for baking than apples', 'Apples are better for baking than peaches'))
# ('Fruits', ('Oranges are a better snack than apples', 'Apples are a better snack than oranges'))
# ('Fruits', ('Pears are underrated compared to apples', 'Apples are more appreciated than pears'))
# ('Fruits', ('Avocados are technically fruits', 'Avocados are not commonly thought of as fruits'))
# ('Fruits', ('Nut butters enhance fruit flavors', 'Nut butters overpower fruit flavors'))
# ('Fruits', ('Fresh fruit is superior to canned fruit', 'Canned fruit can be just as good as fresh fruit'))
# ('Fruits', ("Bananas are nature's perfect snack", "Apples are nature's perfect snack"))
# ('Fruits', ('Ripe avocado is creamier than ripe banana', 'Ripe banana is creamier than ripe avocado'))
# ('Fruits', ('Coconut water is healthier than fruit juices', 'Fruit juices are healthier than coconut water'))
# ('Fruits', ('Fruit smoothies are better than fruit juices', 'Fruit juices are better than fruit smoothies'))
# ('Fruits', ('Citrus peels are useful in cooking', 'Citrus peels have no culinary use'))
# ('Fruits', ('Freshly squeezed orange juice beats store-bought', 'Store-bought orange juice is just as good'))
# ('Fruits', ('Fruits should be stored in the fridge', 'Fruits should not be stored in the fridge'))
# ('Fruits', ('Sweet cherries are better than sour cherries', 'Sour cherries have more flavor than sweet cherries'))
# ('Fruits', ('Banana chips are a good alternative to potato chips', 'Banana chips are not a good alternative to potato chips'))
# ('Fruits', ('Fruit desserts are better than chocolate desserts', 'Chocolate desserts are better than fruit desserts'))
# ('Fruits', ('Blackcurrants are more flavorful than white currants', 'White currants are more flavorful than blackcurrants'))
# ('Fruits', ('Apricot jam is better than strawberry jam', 'Strawberry jam is better than apricot jam'))
# ('Fruits', ('Fruit baskets make better gifts than flowers', 'Flowers make better gifts than fruit baskets'))
# ('Fruits', ('Fruit-based energy bars are better than granola bars', 'Granola bars are better than fruit-based energy bars'))
# ('Fruits', ('Kiwi skin is edible', 'Kiwi skin should not be eaten'))
# ('Fruits', ('Oranges are the most popular fruit', 'Bananas are the most popular fruit'))
# ('Fruits', ('Passionfruit is more flavorful than guava', 'Guava is more flavorful than passionfruit'))
# ('Fruits', ('Fruit preserves taste better than fresh fruit', 'Fresh fruit tastes better than fruit preserves'))
# ('Fruits', ('Food pairings with fruits enhance their taste', 'Food pairings with fruits can ruin their taste'))
# ('Fruits', ('Tropical fruits are better than temperate fruits', 'Temperate fruits are better than tropical fruits'))
# ('Fruits', ('Frozen berries are better for baking than fresh', 'Fresh berries are better for baking than frozen'))
# ('Fruits', ('Fruit-infused water is worth the hype', 'Fruit-infused water is overrated'))
# ('Fruits', ('Cut fruits spoil faster than whole fruits', 'Whole fruits spoil faster than cut fruits'))
# ('Fruits', ('Honeydew is the best melon', 'Cantaloupe is the best melon'))
# ('Fruits', ('Sweet vs. tart fruits: sweet is better', 'Sweet vs. tart fruits: tart is better'))
# ('Fruits', ('Rambutan is more exotic than lychee', 'Lychee is more exotic than rambutan'))
# ('Fruits', ('Eating seasonal fruits is more enjoyable', 'Eating imported fruits is just as enjoyable'))
# ('Fruits', ('Eating fruits provides more energy than eating grains', 'Eating grains provides more energy than eating fruits'))
# ('Fruits', ('Fruit-based diets are effective for weight loss', 'Fruit-based diets are not effective for weight loss'))
# ('Fruits', ('Fruit purées are better than fruit chunks in desserts', 'Fruit chunks are better than fruit purées in desserts'))
# ('Fruits', ('Pineapples can be enjoyed fresh or canned', 'Canned pineapples are inferior to fresh'))
# ('Fruits', ('Fruit themed parties are more fun', 'Fruit themed parties are not enjoyable'))
# ('Fruits', ('Eating the skin of fruits is beneficial', 'Eating the skin of fruits is not beneficial'))
# ('Fruits', ('Fruit popsicles are superior to ice cream', 'Ice cream is superior to fruit popsicles'))
# ('Fruits', ('Grapefruit adds more flavor to salads', 'Apples add more flavor to salads'))
# ('Fruits', ('Fruit flavors should be used in more savory dishes', 'Fruit flavors should stay in desserts'))
# ('Fruits', ('Fruit stands are the best place to buy produce', 'Supermarkets are the best place to buy produce'))
# ('Fruits', ('Peaches are the best fruit to eat in the summer', 'Watermelon is the best fruit to eat in the summer'))
# ('Fruits', ('Fruit contributes to better skin health', 'Fruit does not significantly contribute to skin health'))
# ('Fruits', ('Cooking fruits enhances their flavor', 'Cooking fruits diminishes their flavor'))
# ('Fruits', ('Fruit smoothies are a balanced meal', 'Fruit smoothies cannot replace a balanced meal'))
# ('Fruits', ('Acai berries are overrated', 'Acai berries are not overrated'))
# ('Fruits', ('Handpicked fruits are tastier than store-bought', 'Store-bought fruits can taste just as good'))
# ('Fruits', ('Fruit thinnings are beneficial for trees', 'Fruit thinnings are detrimental for trees'))
# ('Fruits', ('Fruit-flavored candies taste better than fruit', 'Fruit tastes better than fruit-flavored candies'))
# ('Fruits', ('Dried mango is a great snack option', 'Fresh mango is a better snack option'))
# ('Fruits', ('Mediterranean fruits are superior to tropical fruits', 'Tropical fruits are superior to Mediterranean fruits'))
# ('Fruits', ('Indigenous fruits are underappreciated', 'Global fruits are better appreciated'))
# ('Fruits', ('Fruit trees should be included in urban planning', 'Fruit trees are not necessary in urban planning'))
# ('Fruits', ('Fruit bowls are a better decoration than flowers', 'Flowers are a better decoration than fruit bowls'))
# ('Fruits', ('Cooked apples are better than raw apples', 'Raw apples are better than cooked apples'))
# ('Fruits', ('Fruit textures can affect preference', 'Fruit colors can affect preference'))
# ('Fruits', ('Fruit smoothies are healthier than milkshakes', 'Milkshakes can be healthier than fruit smoothies'))
# ('Fruits', ('Fruit can be addictive', 'Fruit is not addictive'))
# ('Fruits', ('Sugar content should be more emphasized in fruits', 'Sugar content should not be a concern for fruits'))
# ('Fruits', ('Individual fruits offer unique health benefits', 'Fruit combinations offer greater health benefits'))
# ('Fruits', ('Fruits should be a primary part of breakfast', 'Fruits should not be the primary part of breakfast'))
# ('Fruits', ('Seasonal fruits are fresher than imported fruits', 'Imported fruits can be just as fresh as seasonal fruits'))
# ('Vegetables', ('Tomatoes are vegetables', 'Tomatoes are fruits'))
# ('Vegetables', ('Carrots are tastier than Peas', 'Peas are tastier than Carrots'))
# ('Vegetables', ('Lettuce is a better salad base than Spinach', 'Spinach is a better salad base than Lettuce'))
# ('Vegetables', ('Broccoli is more nutritious than Cauliflower', 'Cauliflower is more nutritious than Broccoli'))
# ('Vegetables', ('Zucchini is a better vegetable for grilling than Eggplant', 'Eggplant is a better vegetable for grilling than Zucchini'))
# ('Vegetables', ('Bell Peppers are more versatile than Onions', 'Onions are more versatile than Bell Peppers'))
# ('Vegetables', ('Sweet Potatoes are tastier than regular Potatoes', 'Regular Potatoes are tastier than Sweet Potatoes'))
# ('Vegetables', ('Cucumbers are better for hydration than Tomatoes', 'Tomatoes are better for hydration than Cucumbers'))
# ('Vegetables', ('Beets are a better source of iron than Spinach', 'Spinach is a better source of iron than Beets'))
# ('Vegetables', ('Radishes are more flavorful than Carrots', 'Carrots are more flavorful than Radishes'))
# ('Vegetables', ('Kale is healthier than Romaine Lettuce', 'Romaine Lettuce is healthier than Kale'))
# ('Vegetables', ('Mushrooms should be classified as vegetables', 'Mushrooms should not be classified as vegetables'))
# ('Vegetables', ('Green Beans are tastier than Asparagus', 'Asparagus is tastier than Green Beans'))
# ('Vegetables', ('Corn is a better vegetable for grilling than Peppers', 'Peppers are a better vegetable for grilling than Corn'))
# ('Vegetables', ('Avocados are vegetables', 'Avocados are fruits'))
# ('Vegetables', ('Brussels Sprouts are a better side dish than Corn', 'Corn is a better side dish than Brussels Sprouts'))
# ('Vegetables', ('Bok Choy is superior to Cabbage', 'Cabbage is superior to Bok Choy'))
# ('Vegetables', ('Fennel has a better flavor than Celery', 'Celery has a better flavor than Fennel'))
# ('Vegetables', ('Artichokes are more complex to prepare than Carrots', 'Carrots are more complex to prepare than Artichokes'))
# ('Vegetables', ('Pickles are tastier than raw Cucumbers', 'Raw Cucumbers are tastier than Pickles'))
# ('Vegetables', ('Pumpkin is the best fall vegetable', 'Squash is the best fall vegetable'))
# ('Vegetables', ('Shallots are better than Onions', 'Onions are better than Shallots'))
# ('Vegetables', ('Chard is a more effective vegetable for detoxing than Kale', 'Kale is a more effective vegetable for detoxing than Chard'))
# ('Vegetables', ('Jalapeños are more flavorful than Serrano Peppers', 'Serrano Peppers are more flavorful than Jalapeños'))
# ('Vegetables', ('Parsnips are more versatile than Turnips', 'Turnips are more versatile than Parsnips'))
# ('Vegetables', ('Snap Peas are tastier than Snow Peas', 'Snow Peas are tastier than Snap Peas'))
# ('Vegetables', ('Tomatillos are better for salsa than Tomatoes', 'Tomatoes are better for salsa than Tomatillos'))
# ('Vegetables', ('Chayote is tastier than Zucchini', 'Zucchini is tastier than Chayote'))
# ('Vegetables', ('Peppers are better in stir-fry than Carrots', 'Carrots are better in stir-fry than Peppers'))
# ('Vegetables', ('Green Onions are preferred over Yellow Onions', 'Yellow Onions are preferred over Green Onions'))
# ('Vegetables', ('Garlic is more essential than Onion', 'Onion is more essential than Garlic'))
# ('Vegetables', ('Cabbage is tastier than Bok Choy', 'Bok Choy is tastier than Cabbage'))
# ('Vegetables', ('Lima Beans are more nutritious than Green Beans', 'Green Beans are more nutritious than Lima Beans'))
# ('Vegetables', ('Turnips are tastier than Rutabagas', 'Rutabagas are tastier than Turnips'))
# ('Vegetables', ('Celery is a better vegetable for snacking than Carrots', 'Carrots are a better vegetable for snacking than Celery'))
# ('Vegetables', ('Eggplants are a better meat substitute than Mushrooms', 'Mushrooms are a better meat substitute than Eggplants'))
# ('Vegetables', ('Squash is tastier than Zucchini', 'Zucchini is tastier than Squash'))
# ('Vegetables', ('Cilantro is a better herb than Parsley in cooking', 'Parsley is a better herb than Cilantro in cooking'))
# ('Vegetables', ('Sweet Bell Peppers are healthier than Hot Peppers', 'Hot Peppers are healthier than Sweet Bell Peppers'))
# ('Vegetables', ('Napa Cabbage is more versatile than Green Cabbage', 'Green Cabbage is more versatile than Napa Cabbage'))
# ('Vegetables', ('Watercress is a better salad green than Arugula', 'Arugula is a better salad green than Watercress'))
# ('Vegetables', ('Radicchio is tastier than Endive', 'Endive is tastier than Radicchio'))
# ('Vegetables', ('Spanish Onions are better than White Onions', 'White Onions are better than Spanish Onions'))
# ('Vegetables', ('Yellow Squash is preferred over Zucchini for roasting', 'Zucchini is preferred over Yellow Squash for roasting'))
# ('Vegetables', ('Kohlrabi is tastier than Daikon', 'Daikon is tastier than Kohlrabi'))
# ('Vegetables', ('Butter Lettuce is better than Iceberg Lettuce', 'Iceberg Lettuce is better than Butter Lettuce'))
# ('Vegetables', ('Garlic Chives are preferred over regular Chives', 'Regular Chives are preferred over Garlic Chives'))
# ('Vegetables', ('Tomato sauce is better with Fresh Tomatoes than with Canned Tomatoes', 'Tomato sauce is better with Canned Tomatoes than with Fresh Tomatoes'))
# ('Vegetables', ('Collard Greens are more nutritious than Kale', 'Kale is more nutritious than Collard Greens'))
# ('Vegetables', ('Peas are better in pasta than Broccoli', 'Broccoli is better in pasta than Peas'))
# ('Vegetables', ('Vegetable chips are better than potato chips', 'Potato chips are better than vegetable chips'))
# ('Vegetables', ('Aubergine is tastier than Zucchini', 'Zucchini is tastier than Aubergine'))
# ('Vegetables', ('Fried Green Tomatoes are better than grilled Tomatoes', 'Grilled Tomatoes are better than Fried Green Tomatoes'))
# ('Vegetables', ('Sweet Potatoes are better than Butternut Squash', 'Butternut Squash is better than Sweet Potatoes'))
# ('Vegetables', ('Chickpeas are a better base for dips than Lentils', 'Lentils are a better base for dips than Chickpeas'))
# ('Vegetables', ('Asparagus is better steamed than roasted', 'Asparagus is better roasted than steamed'))
# ('Vegetables', ('Radishes are more flavorful than Carrots in salads', 'Carrots are more flavorful than Radishes in salads'))
# ('Vegetables', ('Carrots are better for juicing than Beets', 'Beets are better for juicing than Carrots'))
# ('Vegetables', ('Milkweed is a tastier vegetable than Dandelion greens', 'Dandelion greens are a tastier vegetable than Milkweed'))
# ('Vegetables', ('Chinese Broccoli is more nutritious than Western Broccoli', 'Western Broccoli is more nutritious than Chinese Broccoli'))
# ('Vegetables', ('Pickled vegetables are more delicious than fresh vegetables', 'Fresh vegetables are more delicious than pickled vegetables'))
# ('Vegetables', ('Snap Peas are the best vegetable to eat raw', 'Cucumber is the best vegetable to eat raw'))
# ('Vegetables', ('Fried Eggplant is tastier than Fried Zucchini', 'Fried Zucchini is tastier than Fried Eggplant'))
# ('Vegetables', ('Sesame Seeds are better than Pumpkin Seeds in salads', 'Pumpkin Seeds are better than Sesame Seeds in salads'))
# ('Vegetables', ('Pumpkin puree is better than Sweet Potato puree', 'Sweet Potato puree is better than Pumpkin puree'))
# ('Vegetables', ('Chickory is a better salad green than Romaine', 'Romaine is a better salad green than Chickory'))
# ('Vegetables', ('Carrots are better in curry than Potatoes', 'Potatoes are better in curry than Carrots'))
# ('Vegetables', ('Jerusalem artichokes are tastier than regular artichokes', 'Regular artichokes are tastier than Jerusalem artichokes'))
# ('Vegetables', ('Kale chips are better than Potato chips', 'Potato chips are better than Kale chips'))
# ('Vegetables', ('Cabbage is a better ingredient for slaw than Carrots', 'Carrots are a better ingredient for slaw than Cabbage'))
# ('Vegetables', ('Lentils are tastier than Black Beans', 'Black Beans are tastier than Lentils'))
# ('Vegetables', ('Basil is a better seasoning than Oregano', 'Oregano is a better seasoning than Basil'))
# ('Vegetables', ('Salad greens are better for your diet than starchy vegetables', 'Starchy vegetables are better for your diet than salad greens'))
# ('Vegetables', ('Chili Peppers are more flavorful than Bell Peppers', 'Bell Peppers are more flavorful than Chili Peppers'))
# ('Vegetables', ('Cauliflower is better for making rice than Broccoli', 'Broccoli is better for making rice than Cauliflower'))
# ('Vegetables', ('Parsnips are a better substitute for potatoes than Rutabaga', 'Rutabaga is a better substitute for potatoes than Parsnips'))
# ('Vegetables', ('Pumpkin soup is tastier than Tomato soup', 'Tomato soup is tastier than Pumpkin soup'))
# ('Vegetables', ('Spinach is better in smoothies than Kale', 'Kale is better in smoothies than Spinach'))
# ('Vegetables', ('Broccoli is more appealing than Brussels Sprouts', 'Brussels Sprouts is more appealing than Broccoli'))
# ('Vegetables', ('Sweet Potatoes belong in more dishes than regular Potatoes', 'Regular Potatoes belong in more dishes than Sweet Potatoes'))
# ('Vegetables', ('Artichoke dip tastes better than Spinach dip', 'Spinach dip tastes better than Artichoke dip'))
# ('Vegetables', ('Green Peppers are better in onion rings than Red Peppers', 'Red Peppers are better in onion rings than Green Peppers'))
# ('Vegetables', ('Eggplant Parmesan is better than Chicken Parmesan', 'Chicken Parmesan is better than Eggplant Parmesan'))
# ('Vegetables', ('Corn on the cob is tastier than Creamed Corn', 'Creamed Corn is tastier than Corn on the cob'))
# ('Vegetables', ('Celery juice is healthier than Carrot juice', 'Carrot juice is healthier than Celery juice'))
# ('Vegetables', ('Cauliflower is a better pizza crust than Eggplant', 'Eggplant is a better pizza crust than Cauliflower'))
# ('Vegetables', ('Radish greens should be eaten more than Beet greens', 'Beet greens should be eaten more than Radish greens'))
# ('Vegetables', ('Mushrooms are better in stir-fry than Peas', 'Peas are better in stir-fry than Mushrooms'))
# ('Vegetables', ('Zucchini bread is a better dessert than Carrot cake', 'Carrot cake is a better dessert than Zucchini bread'))
# ('Vegetables', ('Fresh Veggies are better than Frozen Veggies', 'Frozen Veggies are better than Fresh Veggies'))
# ('Vegetables', ('Cauliflower rice is superior to Quinoa', 'Quinoa is superior to Cauliflower rice'))
# ('Vegetables', ('Cabbage rolls are tastier than Stuffed Peppers', 'Stuffed Peppers are tastier than Cabbage rolls'))
# ('Vegetables', ('Radish sprouts are tastier than Alfalfa sprouts', 'Alfalfa sprouts are tastier than Radish sprouts'))
# ('Vegetables', ('Pesto made with Kale is better than Pesto made with Basil', 'Pesto made with Basil is better than Pesto made with Kale'))
# ('Vegetables', ('Black-eyed peas are more nutritious than Chickpeas', 'Chickpeas are more nutritious than Black-eyed peas'))
# ('Vegetables', ('Turnips are better roasted than Carrots', 'Carrots are better roasted than Turnips'))
# ('Vegetables', ('Arugula is a better topping on pizza than Spinach', 'Spinach is a better topping on pizza than Arugula'))
# ('Vegetables', ('Vegetable stir-fries are more nutritious than meat stir-fries', 'Meat stir-fries are more nutritious than vegetable stir-fries'))
# ('Vegetables', ('Sweet Corn is tastier than Field Corn', 'Field Corn is tastier than Sweet Corn'))
# ('Vegetables', ('Garlic is a better flavor enhancer than Ginger', 'Ginger is a better flavor enhancer than Garlic'))
# ('Technology', ('We should prioritize renewable energy technology', 'We should invest more in fossil fuel technologies'))
# ('Technology', ('Artificial intelligence will improve our lives', 'Artificial intelligence poses a threat to humanity'))
# ('Technology', ('We should ban facial recognition technology', 'Facial recognition technology is vital for security'))
# ('Technology', ('Online learning is more effective than traditional classroom learning', 'Traditional classroom learning is more effective than online learning'))
# ('Technology', ('Government surveillance is necessary for security', 'Government surveillance infringes on personal privacy'))
# ('Technology', ('Social media has a positive impact on society', 'Social media has a negative impact on society'))
# ('Technology', ('We should implement stricter regulations on tech companies', 'Stricter regulations will stifle innovation in tech companies'))
# ('Technology', ('Video games are beneficial for cognitive development', "Video games negatively impact children's behavior"))
# ('Technology', ('We should invest in space exploration', 'We should prioritize solving problems on Earth before exploring space'))
# ('Technology', ('Robots should be allowed to replace human workers', 'Humans should always be prioritized over robots in the workforce'))
# ('Technology', ('The benefits of cryptocurrency outweigh the risks', 'The risks of cryptocurrency outweigh the benefits'))
# ('Technology', ('Virtual reality will revolutionize education', 'Virtual reality is not a practical solution for education'))
# ('Technology', ('Smartphones improve our quality of life', 'Smartphones create more problems than they solve'))
# ('Technology', ('Genetic engineering will lead to a better future', 'Genetic engineering poses ethical dilemmas that we should avoid'))
# ('Technology', ('The digital divide is widening and needs urgent attention', 'The digital divide is not as significant as it seems'))
# ('Technology', ('Telecommuting is better for productivity', 'In-office work leads to better productivity'))
# ('Technology', ('Technology can solve climate change', 'Technology cannot solve climate change; we need behavioral change'))
# ('Technology', ('Artificial intelligence should have ethical guidelines', 'Artificial intelligence should not be limited by ethical guidelines'))
# ('Technology', ('Biometric data should be stored for security purposes', 'Storing biometric data is an invasion of privacy'))
# ('Technology', ('Self-driving cars will reduce traffic accidents', 'Self-driving cars can create new risks on the road'))
# ('Technology', ('The rise of automation will improve our economy', 'The rise of automation will harm our economy'))
# ('Technology', ('We should promote open-source software', 'Proprietary software is necessary for innovation'))
# ('Technology', ('E-books are better than physical books', 'Physical books provide a unique reading experience that e-books lack'))
# ('Technology', ('Drones should be used for delivery services', 'Drones pose too many risks to public safety'))
# ('Technology', ('Online privacy is a myth', 'Online privacy can be effectively protected'))
# ('Technology', ('Augmented reality will change consumer shopping habits', 'Augmented reality is just a novelty and will not last'))
# ('Technology', ('The benefits of 5G technology outweigh the concerns', '5G technology poses too many health risks to be implemented widely'))
# ('Technology', ('We should prioritize research in quantum computing', 'Quantum computing does not provide enough immediate benefits'))
# ('Technology', ('Social media platforms should regulate misinformation', 'Regulating misinformation infringes on free speech'))
# ('Technology', ('All schools should have access to coding education', 'Coding education is not necessary for all students'))
# ('Technology', ('Technology increases our sense of connection', 'Technology leads to social isolation'))
# ('Technology', ('Wearable technology is essential for health monitoring', 'Wearable technology is unnecessary and invasive'))
# ('Technology', ('The rise of e-commerce harms local businesses', 'E-commerce boosts economic growth'))
# ('Technology', ('Internet access should be considered a human right', 'Internet access should not be classified as a human right'))
# ('Technology', ('We should invest in AI for healthcare', 'AI in healthcare could lead to potential misuse'))
# ('Technology', ('Voice assistants improve daily convenience', 'Voice assistants compromise our privacy and security'))
# ('Technology', ('Data mining practices are necessary for business', 'Data mining violates consumer privacy'))
# ('Technology', ('We should embrace genetic editing technologies', 'Genetic editing technologies are too risky to embrace'))
# ('Technology', ('Tech corporations have too much power in society', 'Tech corporations drive progress and innovation'))
# ('Technology', ('Blockchain is the future of secure transactions', 'Blockchain technology is overhyped and unnecessary'))
# ('Technology', ('Smart homes represent the future of living', 'Smart homes introduce significant security vulnerabilities'))
# ('Technology', ('Frequent technology upgrades enhance productivity', 'Constant upgrades create more chaos than efficiency'))
# ('Technology', ('Cryptocurrencies will replace traditional currencies', 'Cryptocurrencies will never replace traditional currencies'))
# ('Technology', ('Online gaming communities are positive spaces', 'Online gaming communities can foster toxicity'))
# ('Technology', ('We should take advantage of AI in government', 'Government use of AI could lead to discrimination'))
# ('Technology', ('Mobile payments are the future of transactions', 'Mobile payments could lead to security issues'))
# ('Technology', ('Crowdsourcing is an effective way to solve problems', 'Crowdsourcing leads to unreliable solutions'))
# ('Technology', ('Technological advancements empower individuals', 'Technological advancements create dependencies'))
# ('Technology', ('Driverless trucks will improve freight transport efficiency', 'Driverless trucks will cause loss of jobs and industry disruption'))
# ('Technology', ('The future of banking lies in digital currencies', 'Digital currencies are too volatile for banking stability'))
# ('Technology', ('We should invest in tech education for underserved communities', 'Current efforts towards tech education are sufficient'))
# ('Technology', ('Artificial intelligence will surpass human intelligence', 'Human intelligence will always be superior to AI'))
# ('Technology', ('Biometric security measures are safer than passwords', 'Biometric data can be easily compromised'))
# ('Technology', ('Technology can help us achieve world peace', 'Technology is a tool for conflict rather than peace'))
# ('Technology', ('Remote work should become the new standard', 'Remote work lacks essential face-to-face interaction'))
# ('Technology', ('Technology can enhance democratic engagement', 'Technology undermines the democratic process'))
# ('Technology', ('Coding should be mandatory in schools', 'Teaching coding is misleading and unnecessary for most students'))
# ('Technology', ('Gaming addiction should be considered a mental health issue', 'Gaming addiction is often exaggerated'))
# ('Technology', ('Tech giants should be broken up to ensure competition', 'Breaking up tech giants will lead to less innovation'))
# ('Technology', ('The gig economy benefits workers', 'The gig economy exploits workers'))
# ('Technology', ('We should allow AI to make healthcare decisions', 'AI should not make decisions in healthcare'))
# ('Technology', ('Smartphones have replaced traditional communication', 'Traditional communication methods remain essential'))
# ('Technology', ('We should prioritize cybersecurity in national defense', 'Other defense priorities should take precedence over cybersecurity'))
# ('Technology', ('Teen access to technology needs to be regulated', 'Teens should have the freedom to use technology as they wish'))
# ('Technology', ('Older generations should embrace new technologies', 'Older generations should be allowed to manage technology at their own pace'))
# ('Technology', ('Artificial intelligence will eliminate the need for human oversight', 'Human oversight will always be necessary in AI'))
# ('Technology', ('Data should only be collected for specific purposes', 'Data should be collected broadly for comprehensive analysis'))
# ('Technology', ('The benefits of social media for communication are greater than the drawbacks', 'The drawbacks of social media for communication far outweigh the benefits'))
# ('Technology', ('Technology will eradicate poverty', 'Technology cannot solve the systemic issues contributing to poverty'))
# ('Technology', ('Augmented reality is the future of entertainment', 'Augmented reality lacks practicality and appeal'))
# ('Technology', ('We should invest in tech solutions for environmental issues', 'Tech solutions distract from systemic environmental change'))
# ('Technology', ('Cyberbullying is a serious issue that should be addressed', 'Cyberbullying is less harmful than in-person bullying'))
# ('Technology', ('Artificial intelligence should replace judges in legal decisions', 'Judges are irreplaceable due to human judgment'))
# ('Technology', ('We should create laws for ethical AI development', 'Regulating ethical AI development could stifle innovation'))
# ('Technology', ('Educational institutions should integrate AI into curricula', 'AI integration in education should be approached with caution'))
# ('Technology', ('The potential of virtual reality outweighs its limitations', 'Virtual reality is not practical for widespread use'))
# ('Technology', ('We should invest in clean technology', 'Clean technology is too expensive to implement'))
# ('Technology', ('The internet of things will improve quality of life', 'The internet of things creates security vulnerabilities'))
# ('Technology', ('We should limit smart device usage among children', 'Children should be free to use smart devices for learning'))
# ('Technology', ('Digital detoxes are unnecessary', 'Digital detoxes can enhance mental well-being'))
# ('Technology', ('Hacktivism is a legitimate form of protest', 'Hacktivism is a criminal act that should be punished'))
# ('Technology', ('Technology will improve personalized healthcare', 'Personalized healthcare driven by technology poses ethical concerns'))
# ('Technology', ('Artificial intelligence should assist in creative processes', 'AI should not take part in creative processes'))
# ('Technology', ('The rise of surveillance technology is justified', 'Surveillance technology is an invasion of privacy'))
# ('Technology', ('Space tourism will boost technological advancements', 'Space tourism is a waste of resources'))
# ('Technology', ('Digital literacy should be a priority in schools', 'Schools should focus on core subjects rather than digital literacy'))
# ('Technology', ('We should legalize drone delivery services', 'Drone delivery services pose risks to privacy and safety'))
# ('Technology', ('The future of communication lies in virtual meetings', 'In-person meetings are irreplaceable for effective communication'))
# ('Technology', ('AI assistants will enhance personal productivity', 'AI assistants create distractions rather than enhance productivity'))
# ('Technology', ('Online platforms should bear more responsibility for content', 'Users should be primarily responsible for their content'))
# ('Technology', ('Tech innovations will lead to improved food security', 'Tech innovations may not address the real issues of food security'))
# ('Technology', ('Artificial intelligence can aid in environmental conservation', 'Relying on AI for environmental conservation is risky'))
# ('Technology', ('Smart transportation systems will reduce urban congestion', 'Smart transportation systems may not be effective in all cities'))
# ('Technology', ('Coding bootcamps are an effective alternative to traditional education', 'Coding bootcamps lack the depth of traditional education'))
# ('Technology', ('Regulations on artificial intelligence should be strict', 'Too much regulation on AI will hamper its development'))
# ('Technology', ('Mobile technology enhances accessibility for disabled individuals', 'Mobile technology may not adequately address all accessibility needs'))
# ('Technology', ('Electric vehicles are the future of transportation', 'Electric vehicles are not a fully sustainable solution'))
# ('Technology', ('Online dating apps improve modern relationships', 'Online dating apps complicate the dating process'))
# ('Technology', ('We should embrace AI in art and music', 'AI in art and music dilutes human creativity'))
# ('Technology', ('Technology can bridge cultural divides', 'Technology can exacerbate cultural divides'))
# ('Economics and Policy', ('We should increase the tax on the rich', 'We should not increase tax on the rich'))
# ('Economics and Policy', ('Universal basic income (UBI) is a viable solution to poverty', 'UBI would create disincentives to work'))
# ('Economics and Policy', ('The minimum wage should be increased', 'Increasing minimum wage leads to job losses'))
# ('Economics and Policy', ('Government should provide free healthcare for all', 'Free healthcare leads to increased taxes and inefficiency'))
# ('Economics and Policy', ('Public education should be funded at higher levels', 'Increased funding is not always effective for improving education'))
# ('Economics and Policy', ('The gig economy should be regulated more', 'Excessive regulation harms flexibility and job creation'))
# ('Economics and Policy', ('Monetary policy should prioritize inflation control', 'Monetary policy should prioritize unemployment reduction'))
# ('Economics and Policy', ('Free trade agreements benefit economies', 'Free trade harms local industries'))
# ('Economics and Policy', ('Carbon taxes are essential for combating climate change', 'Carbon taxes hurt businesses and consumers'))
# ('Economics and Policy', ('Cryptocurrencies should be regulated by governments', 'Regulating cryptocurrencies stifles innovation'))
# ('Economics and Policy', ('Rent control is an effective housing policy', 'Rent control leads to housing shortages'))
# ('Economics and Policy', ('We should implement wealth taxes', 'We should not implement wealth taxes as they are burdensome'))
# ('Economics and Policy', ('Economic globalization is beneficial', 'Globalization harms domestic economies and jobs'))
# ('Economics and Policy', ('Student debt forgiveness is necessary', 'Student debt forgiveness is unfair to those who paid their loans'))
# ('Economics and Policy', ('Corporate subsidies should be eliminated', 'Corporate subsidies are necessary for economic growth'))
# ('Economics and Policy', ('The government should intervene in markets during crises', 'Market forces should be allowed to operate without interference'))
# ('Economics and Policy', ('Fiscal stimulus is effective in a recession', 'Fiscal stimulus leads to long-term debt problems'))
# ('Economics and Policy', ('A universal healthcare system is a human right', 'Universal healthcare lowers the quality of medical services'))
# ('Economics and Policy', ('Banning fossil fuels is necessary to save the planet', 'Banning fossil fuels would lead to economic collapse'))
# ('Economics and Policy', ('The central bank should pursue aggressive monetary policy', 'Aggressive monetary policy risks hyperinflation'))
# ('Economics and Policy', ('Affirmative action in hiring is necessary', 'Affirmative action leads to reverse discrimination'))
# ('Economics and Policy', ('Trade tariffs protect American jobs', 'Trade tariffs harm consumers and the economy'))
# ('Economics and Policy', ('We should prioritize economic growth over environmental protection', 'Sustainable practices can drive economic growth'))
# ('Economics and Policy', ('Privatizing public services is better', 'Public services should remain under government control'))
# ('Economics and Policy', ('Social safety nets reduce poverty effectively', 'Social safety nets create dependency'))
# ('Economics and Policy', ('Mandatory paid family leave is essential', 'Mandatory family leave burdens small businesses'))
# ('Economics and Policy', ('The government should control the housing market', 'Market-driven housing is more efficient'))
# ('Economics and Policy', ('Digital currencies could replace traditional currencies', 'Digital currencies pose risks to economic stability'))
# ('Economics and Policy', ('Economic sanctions are effective foreign policy tools', 'Sanctions often hurt innocent civilians more than regimes'))
# ('Economics and Policy', ('The wealth gap should be addressed through policy', 'The wealth gap is a natural result of capitalism'))
# ('Economics and Policy', ('Fast fashion should be regulated due to its environmental impact', 'Fast fashion provides affordable clothing options'))
# ('Economics and Policy', ('Raising the retirement age is necessary', 'Raising the retirement age is unfair to older workers'))
# ('Economics and Policy', ('Financial education should be mandatory in schools', 'Financial education should be the responsibility of parents'))
# ('Economics and Policy', ('Big businesses should face higher taxes', 'Higher taxes on businesses discourage investment'))
# ('Economics and Policy', ('Artificial intelligence will lead to mass unemployment', 'AI will create new job opportunities'))
# ('Economics and Policy', ('Corporate social responsibility should be mandatory', 'Companies should focus solely on profit'))
# ('Economics and Policy', ('The government should invest in renewable energy', 'Private companies should drive renewable energy development'))
# ('Economics and Policy', ('Healthcare should be treated as a commodity', 'Healthcare is a right, not a privilege'))
# ('Economics and Policy', ('Workplace diversity should be enforced', 'Workplace diversity should be voluntary and based on merit'))
# ('Economics and Policy', ('The economy should be prioritized over public health during pandemics', 'Public health should be prioritized over economic growth'))
# ('Economics and Policy', ('Tax loopholes should be closed', 'Tax loopholes stimulate investment and growth'))
# ('Economics and Policy', ('The government should take a role in regulating the tech industry', 'The tech industry should be free from government interference'))
# ('Economics and Policy', ('Affordable housing initiatives should be government-sponsored', 'Affordable housing is best provided by private markets'))
# ('Economics and Policy', ('Public transportation should be free', 'Free public transportation is not sustainable'))
# ('Economics and Policy', ('Foreign aid is necessary for global stability', 'Foreign aid creates dependence and is often mismanaged'))
# ('Economics and Policy', ('The minimum wage should be indexed to inflation', 'Indexing minimum wage creates instability'))
# ('Economics and Policy', ('Economic growth must be sustainable', 'Rapid economic growth is necessary for development'))
# ('Economics and Policy', ('Internet access is a basic human right', 'Access to the internet should not be viewed as a right'))
# ('Economics and Policy', ('The government should regulate the financial sector more', 'Over-regulation of finance stifles innovation'))
# ('Economics and Policy', ('Investing in education is the best policy for long-term economic growth', 'Other areas need investment for effective growth'))
# ('Economics and Policy', ('Oil subsidies should be eliminated', 'Oil subsidies are necessary for energy security'))
# ('Economics and Policy', ('Productivity should dictate wages', 'Wages should consider cost of living'))
# ('Economics and Policy', ('The government should provide monetary incentives for green energy', 'Market forces should determine energy sources'))
# ('Economics and Policy', ('Taxing the ultra-rich is essential for equity', 'Higher taxes on the wealthy lead to capital flight'))
# ('Economics and Policy', ('Expanding the welfare state is a positive development', 'Welfare expansion increases government dependency'))
# ('Economics and Policy', ('Digital tax on tech giants is justified', 'Digital taxation risks harming innovation'))
# ('Economics and Policy', ('Public debt is a pressing concern', 'Public debt can stimulate economic growth'))
# ('Economics and Policy', ('Sustainable agriculture practices should be mandated', 'Farmers should choose practices based on market demand'))
# ('Economics and Policy', ('Investing in infrastructure is critical for economic success', 'Too much infrastructure investment leads to waste'))
# ('Economics and Policy', ('Intellectual property laws stifle innovation', 'Intellectual property laws are crucial for protecting inventors'))
# ('Economics and Policy', ('The gig economy creates more harm than good', 'The gig economy provides flexibility and new opportunities'))
# ('Economics and Policy', ('New tariffs are necessary to protect domestic industries', 'Tariffs lead to trade wars and economic inefficiency'))
# ('Economics and Policy', ('Financial regulations should be loosened', 'Strengthened regulations are necessary to prevent crises'))
# ('Economics and Policy', ('Government assistance should prioritize the unemployed', 'Assistance should focus on families with children'))
# ('Economics and Policy', ('Inflation targeting is the most effective monetary policy', 'Inflation targeting can create other economic issues'))
# ('Economics and Policy', ('The government should regulate environmental practices of businesses', 'Businesses should self-regulate for sustainability'))
# ('Economics and Policy', ('Mandatory health insurance should be implemented', 'Mandatory health insurance infringes on personal freedom'))
# ('Economics and Policy', ('Technological advancement requires more government oversight', 'Innovation thrives with minimal government involvement'))
# ('Economics and Policy', ('Economic inequality leads to social unrest', 'Economic inequality can drive competition and innovation'))
# ('Economics and Policy', ('Childcare costs should be subsidized by the government', 'Subsidies create market distortions'))
# ('Economics and Policy', ('Investing in mental health services is vital for the economy', 'Mental health is a personal responsibility'))
# ('Economics and Policy', ('The government should enforce living wages', 'Businesses should determine wages based on market conditions'))
# ('Economics and Policy', ('Cryptocurrency can replace traditional banking systems', 'Traditional banks provide stability that cryptocurrency lacks'))
# ('Economics and Policy', ('Inflation is a more significant concern than unemployment', 'Unemployment poses a greater threat to society'))
# ('Economics and Policy', ('Urbanization should be managed by policy', 'Urbanization should happen naturally without interference'))
# ('Economics and Policy', ('Small businesses should receive more government support', 'Market forces are enough to determine business success'))
# ('Economics and Policy', ('The fashion industry should adopt ethical standards', 'Consumer choice should dictate fashion practices'))
# ('Economics and Policy', ('Teleworking should become the norm', 'In-person work fosters better collaboration'))
# ('Economics and Policy', ('Venture capital should be incentivized', 'Venture capital leads to inequality in investment opportunities'))
# ('Economics and Policy', ('Public pensions should be protected', 'Public pensions are unsustainable long-term'))
# ('Economics and Policy', ('A strong social contract is essential in economics', 'Economic freedoms should not be limited for social commitments'))
# ('Economics and Policy', ('Food security should be a government priority', 'Food production should be driven by market demand'))
# ('Economics and Policy', ('Bank bailouts are necessary in crisis situations', 'Bank bailouts encourage reckless behavior'))
# ('Economics and Policy', ('LGBTQ+ rights should be enshrined in economic policies', 'Economic policies should be neutral to social issues'))
# ('Economics and Policy', ('Consumer protection laws are necessary', 'Consumer protection creates undue burdens on businesses'))
# ('Economics and Policy', ('Higher taxes should be levied on the financial sector', 'Higher taxes on finance hamper economic growth'))
# ('Economics and Policy', ('Seasonal work should be protected by policy', 'Seasonal work agreements should be market-driven'))
# ('Economics and Policy', ('Short-term economic gains undermine long-term sustainability', 'Rapid economic growth is critical to address immediate issues'))
# ('Economics and Policy', ('Governments should invest in AI development', 'Market should lead in AI innovation without government involvement'))
# ('Economics and Policy', ('Environmental regulations should be stricter', 'Stricter regulations can hinder business growth'))
# ('Economics and Policy', ('Art and culture should be funded by the government', 'Art and culture should be funded through private initiatives'))
# ('Economics and Policy', ('The tech industry should be taxed more heavily', 'High taxes on tech companies inhibit growth'))
# ('Economics and Policy', ('Financial markets require greater transparency', 'Excessive transparency leads to market inefficiency'))
# ('Economics and Policy', ('Debt relief for developing countries is essential', 'Debt relief creates moral hazard'))
# ('Economics and Policy', ('The economy benefits from increased immigration', 'Increased immigration takes jobs from citizens'))
# ('Economics and Policy', ('Health and wellbeing should be prioritized in economic policy', 'Economic efficiency must take precedence over wellbeing'))
# ('Economics and Policy', ('Developed nations should bear responsibility for climate change', 'Developing nations should also invest in their own solutions'))
# ('Economics and Policy', ('Universal childcare is a necessity for a productive economy', 'Parents should be responsible for childcare'))
# ('Economics and Policy', ('The arts should receive public funding', 'Art should be supported by private donations'))
# ('Economics and Policy', ('Regulating food prices is necessary for health', 'Price controls lead to food shortages'))
# ('Law and Order', ('The death penalty is an effective deterrent against crime', 'The death penalty is not an effective deterrent against crime'))
# ...
# ('Music', ('Historical music is more relevant', 'Contemporary music is more relevant'))
# ('Music', ('The guitar is the most versatile instrument', 'Piano is the most versatile instrument'))
# ('Music', ('Jazz improvisation is more complex', 'Classical composition is more complex'))
# ('Music', ('Festival lineups should prioritize diversity', 'Festival lineups should prioritize popularity'))
# ('Music', ('Instrumental music is more beautiful', 'Vocal music is more beautiful'))
# ('Music', ('Concept albums are more rewarding', 'Single-focused albums are more rewarding'))
# ('Music', ('Classical music is more relaxing', 'Ambient music is more relaxing'))
# ('Music', ('Guitar solos are outdated', 'Guitar solos are timeless'))
# ('Music', ('Censorship in music is necessary', 'Censorship in music is harmful'))
# ('Music', ('Music has more power unconsciously', 'Music has more power consciously'))
# ('Music', ('Nostalgic music is more appealing', 'Innovative music is more appealing'))
# ('Music', ('Music competitions showcase talent better', 'Collaborative music projects showcase talent better'))
# ('Music', ('Dance music is less meaningful', 'Dance music can be meaningful'))
# ('Music', ('Music is better without lyrics', 'Music needs lyrics to be complete'))
# ('Music', ('Music within cultural movements is more significant', 'Individual artist expression is more significant'))
# ('Music', ('Teen pop is more influential for youth', 'Classic rock is more influential for youth'))
# ('Music', ('Opera is the most sophisticated genre', 'Jazz is the most sophisticated genre'))
# ('Music', ('Instrumentals can evoke stronger emotions', 'Vocals can evoke stronger emotions'))
# ('Music', ('Tribute bands lack creativity', 'Tribute bands showcase reverence'))
# ('Music', ('R&B is more soulful', 'Gospel is more soulful'))
# ('Music', ('Music is only a business', 'Music is an art first'))
# ('Music', ('Music from different cultures enriches local music scenes', 'Local music scenes better represent culture'))
# ('Music', ('Hip hop promotes positive change', 'Hip hop promotes negative stereotypes'))
# ('Music', ('YouTube has changed music consumption for the better', 'YouTube has changed music consumption for the worse'))
# ('Music', ('Collab albums are hit-or-miss', 'Collab albums are generally successful'))
# ('Music', ('Live music is essential for community building', 'Recorded music is essential for community building'))
# ('Music', ('Unplugged performances are overhyped', 'Unplugged performances are underappreciated'))
# ('Music', ('Musical genres should evolve', 'Musical genres should stay traditional'))
# ('Music', ('Music festivals are too commercialized', 'Music festivals provide important economic support'))
# ('Music', ('Crossover artists dilute their original genres', 'Crossover artists enrich their original genres'))
# ('Music', ('The evolution of music is inevitable', 'The evolution of music is detrimental'))
# ('Music', ('Underground scenes foster better innovation', 'Mainstream scenes promote better innovation'))
# ('Music', ('Jazz fusion is more exciting than traditional jazz', 'Traditional jazz is more exciting than jazz fusion'))
# ('Music', ('Song covers can introduce new audiences', 'Song covers can obscure original artists'))
# ('Music', ('Regional music should be celebrated', 'Global music should be celebrated'))
# ('Music', ('Musical awards have real significance', 'Musical awards are mostly political'))
# ('Music', ('Traditional instruments are superior', 'Electronic instruments are superior'))
# ('Music', ('Lyrical depth is necessary for good music', 'Catchiness is more important than lyrical depth'))
# ('Music', ('Music can heal', 'Music cannot heal'))
# ('Music', ('Extended play (EP) albums are meaningful', 'Extended play (EP) albums are unnecessary'))
# ('Music', ('Boundaries between genres should be blurred', 'Boundaries between genres should be maintained'))
# ('Music', ('Celebrity influence in music is damaging', 'Celebrity influence in music is beneficial'))
# ('Music', ('Music can change political landscapes', 'Music has no effect on political landscapes'))
# ('Music', ('Album releases should be eventful', 'Casual album releases are preferable'))
# ('Music', ('Soundcloud allows for better music discovery', 'Soundcloud complicates music discovery'))
# ('Music', ('Chamber music has more depth', 'Orchestral music has more depth'))
# ('Music', ('Street performers deserve more recognition', 'Street performers should remain anonymous'))
# ('Music', ('Mash-ups are a form of art', 'Mash-ups lack originality'))
# ('Music', ('Traditional folk music should be preserved', 'Traditional folk music should evolve'))
# ('Music', ('A capella groups show more talent', 'Cover bands show more talent'))
# ('Music', ('Music made for films is just commercial', 'Music made for films is a legitimate art form'))
# ('Music', ('Sophisticated lyrics make good songs', 'Simple lyrics can make good songs'))
# ('Music', ('Heavy metal fans are more devoted', 'Classical music fans are more devoted'))
# ('Music', ('The radio is a key music discovery tool', 'The radio is outdated for music discovery'))
# ('Music', ('Musicians have a responsibility to influence society positively', 'Musicians should focus on personal expression'))
# ('Music', ('Music can promote social change', 'Music is purely entertainment'))
# ('Music', ('Motown is the best era of pop', 'Disco is the best era of pop'))
# ('Music', ('Lyricists are more important than composers', 'Composers are more important than lyricists'))
# ('Music', ('Folk music is timeless', 'Electronic music is timeless'))
# ('Meat', ('Beef is better than Bison', 'Bison is better than Beef'))
# ('Meat', ('Chicken is tastier than Turkey', 'Turkey is tastier than Chicken'))
# ('Meat', ('Pork is more versatile than Lamb', 'Lamb is more versatile than Pork'))
# ('Meat', ('Duck is more flavorful than Chicken', 'Chicken is more flavorful than Duck'))
# ('Meat', ('Grass-fed beef is better than grain-fed beef', 'Grain-fed beef is better than grass-fed beef'))
# ('Meat', ('Salmon is better than Tuna', 'Tuna is better than Salmon'))
# ('Meat', ('Lamb has a better texture than Pork', 'Pork has a better texture than Lamb'))
# ('Meat', ('Venison is healthier than Beef', 'Beef is healthier than Venison'))
# ('Meat', ('Sausage is a better breakfast option than Bacon', 'Bacon is a better breakfast option than Sausage'))
# ('Meat', ('Steak is better when grilled than when pan-seared', 'Steak is better when pan-seared than when grilled'))
# ('Meat', ('Beef jerky is a better snack than Turkey jerky', 'Turkey jerky is a better snack than Beef jerky'))
# ('Meat', ('BBQ ribs are superior to BBQ chicken', 'BBQ chicken is superior to BBQ ribs'))
# ('Meat', ('Pork chops are better than Chicken breasts', 'Chicken breasts are better than Pork chops'))
# ('Meat', ('Fish is a better source of protein than Chicken', 'Chicken is a better source of protein than Fish'))
# ('Meat', ('Fried Chicken is tastier than Baked Chicken', 'Baked Chicken is tastier than Fried Chicken'))
# ('Meat', ('Beef Tacos are better than Chicken Tacos', 'Chicken Tacos are better than Beef Tacos'))
# ('Meat', ('Ground Beef is more versatile than Ground Turkey', 'Ground Turkey is more versatile than Ground Beef'))
# ('Meat', ('Sushi made from Raw Fish is better than Sushi made from Cooked Fish', 'Sushi made from Cooked Fish is better than Sushi made from Raw Fish'))
# ('Meat', ('Brisket is more enjoyable than Pulled Pork', 'Pulled Pork is more enjoyable than Brisket'))
# ('Meat', ('Roasted Chicken trumps Fried Chicken', 'Fried Chicken trumps Roasted Chicken'))
# ('Meat', ('Pork belly is superior to Beef brisket', 'Beef brisket is superior to Pork belly'))
# ('Meat', ('Seafood is better than Red Meat', 'Red Meat is better than Seafood'))
# ('Meat', ('Chorizo is a better sausage than Italian Sausage', 'Italian Sausage is a better sausage than Chorizo'))
# ('Meat', ('Grilled Lamb is better than Grilled Beef', 'Grilled Beef is better than Grilled Lamb'))
# ('Meat', ('Beef stew is better than Chicken noodle soup', 'Chicken noodle soup is better than Beef stew'))
# ('Meat', ('Charcuterie boards with Meats are better than those without', 'Charcuterie boards without Meats are better than those with Meats'))
# ('Meat', ('Smoked Salmon is superior to Smoked Trout', 'Smoked Trout is superior to Smoked Salmon'))
# ('Meat', ('Bison burgers are better than Beef burgers', 'Beef burgers are better than Bison burgers'))
# ('Meat', ('Baked Ham is better than Roast Beef', 'Roast Beef is better than Baked Ham'))
# ('Meat', ('Tandoori Chicken is more flavorful than BBQ Chicken', 'BBQ Chicken is more flavorful than Tandoori Chicken'))
# ('Meat', ('Meatloaf is better than Meatballs', 'Meatballs are better than Meatloaf'))
# ('Meat', ('Roast Duck is superior to Roast Chicken', 'Roast Chicken is superior to Roast Duck'))
# ('Meat', ('Buffalo wings are better than BBQ wings', 'BBQ wings are better than Buffalo wings'))
# ('Meat', ('Steaks from different cuts are better than those from the same cut', 'Steaks from the same cut are better than those from different cuts'))
# ('Meat', ('Carpaccio is a better dish than Tartare', 'Tartare is a better dish than Carpaccio'))
# ('Meat', ('Beef Carpaccio is better than Salmon Carpaccio', 'Salmon Carpaccio is better than Beef Carpaccio'))
# ('Meat', ('Fish and Chips is better than Chicken and Chips', 'Chicken and Chips is better than Fish and Chips'))
# ('Meat', ('Deli Meats are superior to Fresh Meats', 'Fresh Meats are superior to Deli Meats'))
# ('Meat', ('Roasted Lamb is decreed tastier than Roast Pork', 'Roast Pork is decreed tastier than Roasted Lamb'))
# ('Meat', ('Cooking Meat Sous Vide is better than Grilling it', 'Grilling it is better than Cooking Meat Sous Vide'))
# ('Meat', ('Jerky made from beef is better than jerky made from turkey', 'Jerky made from turkey is better than jerky made from beef'))
# ('Meat', ('Lamb burgers are better than Beef burgers', 'Beef burgers are better than Lamb burgers'))
# ('Meat', ('Fish tacos are better than Shrimp tacos', 'Shrimp tacos are better than Fish tacos'))
# ('Meat', ('Cured meats are more appealing than uncured meats', 'Uncured meats are more appealing than cured meats'))
# ('Meat', ('Pulled Chicken is better than Pulled Pork', 'Pulled Pork is better than Pulled Chicken'))
# ('Meat', ('Meat is essential for a healthy diet', 'Meat is not essential for a healthy diet'))
# ('Meat', ('Pastured pork is superior to conventionally raised pork', 'Conventionally raised pork is superior to pastured pork'))
# ('Meat', ('BBQ chicken is better than Fried chicken', 'Fried chicken is better than BBQ chicken'))
# ('Meat', ('Spicy sausages are more enjoyable than mild sausages', 'Mild sausages are more enjoyable than spicy sausages'))
# ('Meat', ('Duck bacon is better than Pork bacon', 'Pork bacon is better than Duck bacon'))
# ('Meat', ('Fish is a better protein source than red meat', 'Red meat is a better protein source than fish'))
# ('Meat', ('Beef is more nutritious than Pork', 'Pork is more nutritious than Beef'))
# ('Meat', ('Organ meats are healthier than muscle meats', 'Muscle meats are healthier than organ meats'))
# ('Meat', ('Stir-fried Chicken is tastier than Stir-fried Beef', 'Stir-fried Beef is tastier than Stir-fried Chicken'))
# ('Meat', ('Meat-based diets are healthier than plant-based diets', 'Plant-based diets are healthier than meat-based diets'))
# ('Meat', ('Buffalo meat is better than Kangaroo meat', 'Kangaroo meat is better than Buffalo meat'))
# ('Meat', ('Meat sauces are better than Meat-based dishes', 'Meat-based dishes are better than Meat sauces'))
# ('Meat', ('Beef skewers are better than Chicken skewers', 'Chicken skewers are better than Beef skewers'))
# ('Meat', ('Cooking Meat in the oven is better than Cooking it on the stove', 'Cooking it on the stove is better than Cooking Meat in the oven'))
# ('Meat', ('Carnitas are better than Barbacoa', 'Barbacoa is better than Carnitas'))
# ('Meat', ('Fish fillets are better than Fish steaks', 'Fish steaks are better than Fish fillets'))
# ('Meat', ('Pork ribs are tastier than Beef ribs', 'Beef ribs are tastier than Pork ribs'))
# ('Meat', ('Chickpea-based sausages are better than meat-based sausages', 'Meat-based sausages are better than chickpea-based sausages'))
# ('Meat', ('Ostrich meat is less appealing than Red meat', 'Red meat is less appealing than Ostrich meat'))
# ('Meat', ('Bratwurst is superior to Hot Dogs', 'Hot Dogs are superior to Bratwurst'))
# ('Meat', ('Fresh turkey is tastier than Processed turkey', 'Processed turkey is tastier than Fresh turkey'))
# ('Meat', ('Chicken Wings are better than Pizza', 'Pizza is better than Chicken Wings'))
# ('Meat', ('Duck confit is better than Fried Chicken', 'Fried Chicken is better than Duck confit'))
# ('Meat', ('Sashimi is better than Ceviche', 'Ceviche is better than Sashimi'))
# ('Meat', ('Surf and Turf is better than a Meat Feast', 'A Meat Feast is better than Surf and Turf'))
# ('Meat', ('Pork Schnitzel is better than Chicken Schnitzel', 'Chicken Schnitzel is better than Pork Schnitzel'))
# ('Meat', ('Beef stew is better with dumplings than without', 'Beef stew is better without dumplings than with'))
# ('Meat', ('Fish tacos are fresher than Meat tacos', 'Meat tacos are fresher than Fish tacos'))
# ('Meat', ('Teriyaki Chicken is tastier than Teriyaki Beef', 'Teriyaki Beef is tastier than Teriyaki Chicken'))
# ('Meat', ('Menudo is better than Pozole', 'Pozole is better than Menudo'))
# ('Meat', ('Meat should be a staple in every meal', 'Meat should not be a staple in every meal'))
# ('Meat', ('Game meats are more flavorful than domesticated meats', 'Domesticated meats are more flavorful than Game meats'))
# ('Meat', ('Veggie burgers can never replace meat burgers', 'Veggie burgers can replace meat burgers'))
# ('Meat', ('Bacon-wrapped anything is better than baconless', 'Baconless anything is better than bacon-wrapped'))
# ('Meat', ('Ceviche is better than Fish and Chips', 'Fish and Chips is better than Ceviche'))
# ('Meat', ('Lamb shanks are more enjoyable than Beef shanks', 'Beef shanks are more enjoyable than Lamb shanks'))
# ('Meat', ('All-Meat Pizzas are better than Veggie Pizzas', 'Veggie Pizzas are better than All-Meat Pizzas'))
# ('Meat', ('Shrimp is a better seafood option than Cod', 'Cod is a better seafood option than Shrimp'))
# ('Meat', ('Pork Rinds are tastier than Potato Chips', 'Potato Chips are tastier than Pork Rinds'))
# ('Meat', ('Beef Tenderloin is the best cut of beef', 'Ribeye is the best cut of beef'))
# ('Meat', ('Sushi is better with raw fish than cooked fish', 'Sushi is better with cooked fish than raw fish'))
# ('Meat', ('Chops are more enjoyable than Steaks', 'Steaks are more enjoyable than Chops'))
# ('Meat', ('Buffalo meat tastes better than beef', 'Beef tastes better than buffalo meat'))
# ('Meat', ('Cooked meat is better than raw meat', 'Raw meat is better than cooked meat'))
# ('Meat', ('Merguez sausages are better than Kielbasa', 'Kielbasa is better than Merguez sausages'))
# ('Meat', ('Fish is more environmentally friendly than red meat', 'Red meat is more environmentally friendly than fish'))
# ('Meat', ('Grilled sausages are better than Fried sausages', 'Fried sausages are better than Grilled sausages'))
# ('Meat', ('Meat should never be frozen if it can be avoided', 'Meat can be frozen without consequences'))
# ('Meat', ('Deep-fried meat is more delicious than baked meat', 'Baked meat is more delicious than deep-fried meat'))
# ('Meat', ('Wild game is tastier than farm-raised meats', 'Farm-raised meats are tastier than wild game'))
# ('Meat', ('Salami is better than Pepperoni', 'Pepperoni is better than Salami'))
# ('Meat', ('Tender cuts of meat are better than tougher cuts', 'Tougher cuts are better than tender cuts'))
# ('Meat', ('Homemade sausage is superior to store-bought', 'Store-bought sausage is superior to homemade'))
# ('Meat', ('Lamb chops are better than Beef steaks', 'Beef steaks are better than Lamb chops'))
# ('Meat', ('Meat-based meals are more filling than plant-based meals', 'Plant-based meals are more filling than meat-based meals'))

# %%
d = TextDataset("topics")

# %%
d[109]
# Out:
# ('vegetables',
#  ('radishes are more flavorful than carrots',
#   'carrots are more flavorful than radishes'))

# %%
d[109][1][1]
# Out:
# 'carrots are more flavorful than radishes'

# %%
curr_top
# Out:
# 'Meat\n'
